# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
X, y = make_circles(n_samples=1000, shuffle=True, noise=0.1, factor=1)

# %%
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])

# %%
np.cov(X.T)
# Out:
# array([[0.50626331, 0.00123706],
#        [0.00123706, 0.50919948]])

# %%
x = np.linspace(start=0, stop=10, num=200)
y = np.sin(x) + np.tan(x)
